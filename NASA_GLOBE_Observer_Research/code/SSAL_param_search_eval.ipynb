# %% [markdown]
# ## Notebook for evaluating parameter search experiments
#
# Allows a user to specify the base name of the experiment being evaluated, creates a list of all of the experiment names, it loops through all of the individual experiments and makes plots showing how well the model trained. These are tests performed outside of the scope of SSAL to see what sort of meta-parameters should be used to get meaningful results such as learning rates, number of epochs etc.

# %%
from SSAL_src.SSAL_evaluation import *

from SSAL_src.SSAL_plotting import *
from SSAL_src.SSAL_classification_vis import *
import ast
import glob

# %%
experiments_list = []
base_experiment_name = "intel_image_param_search_0_"

for i in range(0,6):
    
    exp_name = base_experiment_name + str(i)
    
    experiments_list.append(exp_name)
    
    
experiments_list
# Out:
# ['intel_image_param_search_0_0',
#  'intel_image_param_search_0_1',
#  'intel_image_param_search_0_2',
#  'intel_image_param_search_0_3',
#  'intel_image_param_search_0_4',
#  'intel_image_param_search_0_5']

# %%
#looks at the experiment predictions, calculating results such as accuracy, top2, f1 etc. 
for exper in experiments_list:
    
    compile_experiment_results(exper)
# Out:
# 0
# getting detailed accuracy
# 7
# 7
# 1
# getting detailed accuracy
# 7
# 7
# 2
# getting detailed accuracy
# 7
# 7
# 0
# getting detailed accuracy
# 7
# 7
# 1
# getting detailed accuracy
# 7
# 7
# 2
# getting detailed accuracy
# 7
# 7
# 0
# getting detailed accuracy
# 7
# 7
# 1
# getting detailed accuracy
# 7
# 7
# 2
# getting detailed accuracy
# 7
# 7
# 0
# getting detailed accuracy
# 7
# 7
# 1
# getting detailed accuracy
# 7
# 7
# 2
# getting detailed accuracy
# 7
# 7
# 0
# getting detailed accuracy
# 7
# 7
# 1
# getting detailed accuracy
# 7
# 7
# 2
# getting detailed accuracy
# 7
# 7
# 0
# getting detailed accuracy
# 7
# 7
# 1
# getting detailed accuracy
# 7
# 7
# 2
# getting detailed accuracy
# 7
# 7

# %% [markdown]
# ### Training/Validation Loss/Accuracy plots

# %%
#experiments_list = ["SSAL_mod_test","SSAL_base_test"]
plot_experiments_history(experiments_list)

# %% [markdown]
# ## Experiment Accuracies

# %%
plot_experiment_metric_comparison(experiments_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5c07081e4d12> in <module>
# ----> 1 plot_experiment_metric_comparison(experiments_list)
#
# NameError: name 'plot_experiment_metric_comparison' is not defined

# %% [markdown]
# ## Experiment Top2 Accuracies

# %%
plot_experiment_metric_comparison(experiments_list, metric = "top2")
