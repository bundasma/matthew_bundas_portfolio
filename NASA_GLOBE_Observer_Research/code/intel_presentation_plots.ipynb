# %%
from SSAL_src.SSAL_evaluation import *

from SSAL_src.SSAL_plotting import *
from SSAL_src.SSAL_classification_vis import *
import ast
import glob

# %%
savedirectory = "./presentation_plots/"

# %% [markdown]
# # Intel Base Training Comp Plot Experiment 1 (5)

# %%
savename = "intel_base_compvsiter_1"
make_training_set_comp_plot_experiment("SSAL_exp_5_att5_norestrict_3", title = "Training Set Label Sources vs Iteration - Baseline SSAL", ylim = (0,5000), savename = savedirectory + savename)

# %% [markdown]
# # Intel Mod Training Comp Plot Experiment 1 (5)

# %%
savename = "intel_mod_compvsiter_1"
make_training_set_comp_plot_experiment("SSAL_exp_5_att5_norestrict_4", title = "Training Set Label Sources vs Iteration - Modified SSAL", ylim = (0,11000), savename = savedirectory + savename)

# %% [markdown]
# # Intel Base Training Comp Plot Experiment 2 (0)

# %%
savename = "intel_base_compvsiter_2"
make_training_set_comp_plot_experiment("SSAL_exp_0_att5_norestrict_3", title = "Training Set Label Sources vs Iteration - Base SSAL", ylim = (0,7000), savename = savedirectory + savename)

# %% [markdown]
# # Intel Mod Training Comp Plot Experiment 2 (0)

# %%
savename = "intel_mod_compvsiter_2"
make_training_set_comp_plot_experiment("SSAL_exp_0_att5_norestrict_4", title = "Training Set Label Sources vs Iteration - Modified SSAL", ylim = (0,7000), savename = savedirectory + savename)

# %% [markdown]
# # Intel Base Training Comp Plot Experiment 3 (4)

# %%
savename = "intel_base_compvsiter_3"
make_training_set_comp_plot_experiment("SSAL_exp_4_att4_norestrict_3", title = "Training Set Label Sources vs Iteration - Base SSAL", ylim = (0,5000), savename = savedirectory + savename)

# %% [markdown]
# # Intel Mod Training Comp Plot Experiment 3 (4)

# %%
savename = "intel_mod_compvsiter_3"
make_training_set_comp_plot_experiment("SSAL_exp_4_att4_norestrict_4", title = "Training Set Label Sources vs Iteration - Modified SSAL", ylim = (0,5000), savename = savedirectory + savename)

# %% [markdown]
# # Intel Base Training Comp Plot Experiment 4 (3)

# %%
savename = "intel_base_compvsiter_4"
make_training_set_comp_plot_experiment("SSAL_exp_3_att5_norestrict_3", title = "Training Set Label Sources vs Iteration - Base SSAL", ylim = (0,5000), savename = savedirectory + savename)

# %% [markdown]
# # Intel Mod Training Comp Plot Experiment 4 (3)

# %%
savename = "intel_mod_compvsiter_4"
make_training_set_comp_plot_experiment("SSAL_exp_3_att5_norestrict_4", title = "Training Set Label Sources vs Iteration - Modified SSAL", ylim = (0,5000), savename = savedirectory + savename)

# %% [markdown]
# # Intel AL Distribution Plot Experiment 1 (5)

# %%
savename = "intel_AL_dist_1"

make_al_dist_plot_experiment(["SSAL_exp_5_att5_norestrict_3","SSAL_exp_5_att5_norestrict_4"], dataset = "intel", num_classes = 6, custom_legend_labels = ["Baseline SSAL", "Modified SSAL"], savename = savedirectory + savename)
# Out:
# SSAL_exp_5_att5_norestrict_3
# SSAL_exp_5_att5_norestrict_4

# %% [markdown]
# # Intel AL Distribution Plot Experiment 2 (0)

# %%
savename = "intel_AL_dist_2"

make_al_dist_plot_experiment(["SSAL_exp_0_att5_norestrict_3","SSAL_exp_0_att5_norestrict_4"], dataset = "intel", num_classes = 6, custom_legend_labels = ["Baseline SSAL", "Modified SSAL"], savename = savedirectory + savename)
# Out:
# SSAL_exp_0_att5_norestrict_3
# SSAL_exp_0_att5_norestrict_4

# %% [markdown]
# # Intel AL Distribution Plot Experiment 3 (4)

# %%
savename = "intel_AL_dist_3"

make_al_dist_plot_experiment(["SSAL_exp_4_att4_norestrict_3","SSAL_exp_4_att4_norestrict_4"], dataset = "intel", num_classes = 6, custom_legend_labels = ["Baseline SSAL", "Modified SSAL"], savename = savedirectory + savename)
# Out:
# SSAL_exp_4_att4_norestrict_3
# SSAL_exp_4_att4_norestrict_4

# %% [markdown]
# # Intel AL Distribution Plot Experiment 4 (3)

# %%
savename = "intel_AL_dist_4"

make_al_dist_plot_experiment(["SSAL_exp_3_att5_norestrict_3","SSAL_exp_3_att5_norestrict_4"], dataset = "intel", num_classes = 6, custom_legend_labels = ["Baseline SSAL", "Modified SSAL"], savename = savedirectory + savename)
# Out:
# SSAL_exp_3_att5_norestrict_3
# SSAL_exp_3_att5_norestrict_4

# %% [markdown]
# # Intel SSAL Accuracy vs Num Manual Labeled Exp 1 (5)

# %%
savename = "intel_SSAL_1"

make_al_experiment_plot(["SSAL_exp_5_att5_norestrict_3","SSAL_exp_5_att5_norestrict_4"], custom_legend_labels = ["Baseline SSAL", "Modified SSAL"], savename = savedirectory + savename)

# %% [markdown]
# # Intel SSAL Accuracy vs Num Manual Labeled Exp 2 (0)

# %%
savename = "intel_SSAL_2"

make_al_experiment_plot(["SSAL_exp_0_att5_norestrict_3","SSAL_exp_0_att5_norestrict_4"], custom_legend_labels = ["Baseline SSAL", "Modified SSAL"], savename = savedirectory + savename)

# %% [markdown]
# # Intel SSAL Accuracy vs Num Manual Labeled Exp 3 (4)

# %%
savename = "intel_SSAL_3"

make_al_experiment_plot(["SSAL_exp_4_att4_norestrict_3","SSAL_exp_4_att4_norestrict_4"], custom_legend_labels = ["Baseline SSAL", "Modified SSAL"], savename = savedirectory + savename)

# %% [markdown]
# # Intel SSAL Accuracy vs Num Manual Labeled Exp 4 (3)

# %%
savename = "intel_SSAL_4"

make_al_experiment_plot(["SSAL_exp_3_att5_norestrict_3","SSAL_exp_3_att5_norestrict_4"], custom_legend_labels = ["Baseline SSAL", "Modified SSAL"], savename = savedirectory + savename)

# %% [markdown]
# # Intel Final Test Accuracy - 1 (5)

# %%
savename = "intel_final_accs_1"
title = "Intel Final Test Accuracy Comparison"

custom_anchor = (1.19,1)

plot_experiment_metric_comparison(["SSAL_exp_5_att5_norestrict_5","MAE_exp5_att2","trunc_loss_exp_5_4_0","SSAL_exp_5_att5_norestrict_3","SSAL_exp_5_att5_norestrict_4"], dataset = "intel", num_classes = 6, metric = "accuracy", show_citizens = False, savename = savedirectory + savename, custom_legend_labels = ["Naive Baseline", "MAE","Truncated Loss","Baseline SSAL", "Modified SSAL"], custom_colors = ["#d62728","#2ca02c","#9467bd","#1f77b4","#ff7f0e"], title = title, ylim = (0,110), legend_loc = "upper right", custom_anchor = custom_anchor)

# %% [markdown]
# # Intel Final Test Accuracy - 2 (0)

# %%
savename = "intel_final_accs_2"
title = "Intel Final Test Accuracy Comparison"

custom_anchor = (1.19,1)

plot_experiment_metric_comparison(["SSAL_exp_0_att5_norestrict_5","MAE_exp0_att6","trunc_loss_exp_0_8_4","SSAL_exp_0_att5_norestrict_3","SSAL_exp_0_att5_norestrict_4"], dataset = "intel", num_classes = 6, metric = "accuracy", show_citizens = False, savename = savedirectory + savename, custom_legend_labels = ["Naive Baseline", "MAE","Truncated Loss","Baseline SSAL", "Modified SSAL"], custom_colors = ["#d62728","#2ca02c","#9467bd","#1f77b4","#ff7f0e"], title = title, ylim = (0,110), custom_anchor = custom_anchor)

# %% [markdown]
# # Intel Final Test Accuracy - 3 (4)

# %%
savename = "intel_final_accs_3"
title = "Intel Final Test Accuracy Comparison"

custom_anchor = (1.19,1)


plot_experiment_metric_comparison(["SSAL_exp_4_att4_norestrict_5","MAE_exp4_att2","trunc_loss_exp_4_8_10","SSAL_exp_4_att4_norestrict_3","SSAL_exp_4_att4_norestrict_4"], dataset = "intel", num_classes = 6, metric = "accuracy", show_citizens = False, savename = savedirectory + savename, custom_legend_labels = ["Naive Baseline", "MAE","Truncated Loss","Baseline SSAL", "Modified SSAL"], custom_colors = ["#d62728","#2ca02c","#9467bd","#1f77b4","#ff7f0e"], title = title, ylim = (0,110), custom_anchor = custom_anchor)

# %% [markdown]
# # Intel Final Test Accuracy - 4 (3)

# %%
savename = "intel_final_accs_4"
title = "Intel Final Test Accuracy Comparison"

custom_anchor = (1.19,1)

plot_experiment_metric_comparison(["SSAL_exp_3_att5_norestrict_5","MAE_exp3_att6","trunc_loss_exp_3_8_10","SSAL_exp_3_att5_norestrict_3","SSAL_exp_3_att5_norestrict_4"], dataset = "intel", num_classes = 6, metric = "accuracy", show_citizens = False, savename = savedirectory + savename, custom_legend_labels = ["Naive Baseline", "MAE","Truncated Loss","Baseline SSAL", "Modified SSAL"], custom_colors = ["#d62728","#2ca02c","#9467bd","#1f77b4","#ff7f0e"], title = title, ylim = (0,110), custom_anchor = custom_anchor)

# %% [markdown]
# # Intel Pseudolabel Stats Baseline - Experiment 1

# %%
get_prediction_stats_experiment("SSAL_exp_5_att5_norestrict_3")
# Out:
# total number of predictions 20000.0
# percentage of predictions that are pre-boost confident 0.11385
# percentage of predictiosn that are post-boost confident 0.11385
# total number of post-boost confident predictions 2277.0
# number of predictions that became confident with boost 0
# percentage of confident predictions that are confident because of boost 0.0
# accuracy among confident predictions before boosting 99.18020787586005
# accuracy among confident predictions after boosting 99.18020787586005
# accuracy among confident predictions which switched confident nan
#
#
# total number of pseudolabels 2277.0
# number of pseudolabels that became confident with boost 0.0
# percentage of pseudolabels that are confident because of boost 0.0
# accuracy among pseudolabels before boosting 99.18020787586005
# accuracy among pseudolabels after boosting 99.18020787586005
# accuracy among pseudolabels which switched confident nan
# ...

# %% [markdown]
# # Intel Pseudolabel Stats Mod - Experiment 1

# %%
get_prediction_stats_experiment("SSAL_exp_5_att5_norestrict_4")
# Out:
# total number of predictions 20000.0
# percentage of predictions that are pre-boost confident 0.14603333333333332
# percentage of predictiosn that are post-boost confident 0.4524
# total number of post-boost confident predictions 9048.0
# number of predictions that became confident with boost 18382
# percentage of confident predictions that are confident because of boost 67.72030651340997
# accuracy among confident predictions before boosting 97.69459027619266
# accuracy among confident predictions after boosting 99.25582080754495
# accuracy among confident predictions which switched confident 100.0
#
#
# total number of pseudolabels 9048.0
# number of pseudolabels that became confident with boost 6127.333333333333
# percentage of pseudolabels that are confident because of boost 67.72030651340997
# accuracy among pseudolabels before boosting 97.69459027619266
# accuracy among pseudolabels after boosting 99.25582080754495
# accuracy among pseudolabels which switched confident 100.0
# ...

# %% [markdown]
# # Intel Pseudolabel Stats Baseline - Experiment 2 (0)

# %%
get_prediction_stats_experiment("SSAL_exp_0_att5_norestrict_3")
# Out:
# total number of predictions 20000.0
# percentage of predictions that are pre-boost confident 0.10436666666666666
# percentage of predictiosn that are post-boost confident 0.10436666666666666
# total number of post-boost confident predictions 2087.3333333333335
# number of predictions that became confident with boost 0
# percentage of confident predictions that are confident because of boost 0.0
# accuracy among confident predictions before boosting 99.21750239540083
# accuracy among confident predictions after boosting 99.21750239540083
# accuracy among confident predictions which switched confident nan
#
#
# total number of pseudolabels 2087.3333333333335
# number of pseudolabels that became confident with boost 0.0
# percentage of pseudolabels that are confident because of boost 0.0
# accuracy among pseudolabels before boosting 99.21750239540083
# accuracy among pseudolabels after boosting 99.21750239540083
# accuracy among pseudolabels which switched confident nan
# ...

# %% [markdown]
# # Intel Pseudolabel Stats Mod - Experiment 2 (0)

# %%
get_prediction_stats_experiment("SSAL_exp_0_att5_norestrict_4")
# Out:
# total number of predictions 19621.0
# percentage of predictions that are pre-boost confident 0.10731699029950903
# percentage of predictiosn that are post-boost confident 0.23750063707252433
# total number of post-boost confident predictions 4660.0
# number of predictions that became confident with boost 7663
# percentage of confident predictions that are confident because of boost 54.8140200286123
# accuracy among confident predictions before boosting 97.73626721545037
# accuracy among confident predictions after boosting 98.76967095851215
# accuracy among confident predictions which switched confident 99.62155813650007
#
#
# total number of pseudolabels 4660.0
# number of pseudolabels that became confident with boost 2554.3333333333335
# percentage of pseudolabels that are confident because of boost 54.8140200286123
# accuracy among pseudolabels before boosting 97.73626721545037
# accuracy among pseudolabels after boosting 98.76967095851215
# ...

# %% [markdown]
# # Intel Pseudolabel Stats Baseline - Experiment 3 (4)

# %%
get_prediction_stats_experiment("SSAL_exp_4_att4_norestrict_3")
# Out:
# total number of predictions 19744.333333333332
# percentage of predictions that are pre-boost confident 0.11517228571910929
# percentage of predictiosn that are post-boost confident 0.11517228571910929
# total number of post-boost confident predictions 2274.0
# number of predictions that became confident with boost 0
# percentage of confident predictions that are confident because of boost 0.0
# accuracy among confident predictions before boosting 98.82732336558195
# accuracy among confident predictions after boosting 98.82732336558195
# accuracy among confident predictions which switched confident nan
#
#
# total number of pseudolabels 2274.0
# number of pseudolabels that became confident with boost 0.0
# percentage of pseudolabels that are confident because of boost 0.0
# accuracy among pseudolabels before boosting 98.82732336558195
# accuracy among pseudolabels after boosting 98.82732336558195
# accuracy among pseudolabels which switched confident nan
# ...

# %% [markdown]
# # Intel Pseudolabel Stats Mod - Experiment 3 (4)

# %%
get_prediction_stats_experiment("SSAL_exp_4_att4_norestrict_4")
# Out:
# total number of predictions 14978.666666666666
# percentage of predictions that are pre-boost confident 0.11251557771052163
# percentage of predictiosn that are post-boost confident 0.22184885170019583
# total number of post-boost confident predictions 3323.0
# number of predictions that became confident with boost 4913
# percentage of confident predictions that are confident because of boost 49.2827766074832
# accuracy among confident predictions before boosting 98.02215189873418
# accuracy among confident predictions after boosting 98.63577088975825
# accuracy among confident predictions which switched confident 99.26725015265622
#
#
# total number of pseudolabels 3323.0
# number of pseudolabels that became confident with boost 1637.6666666666667
# percentage of pseudolabels that are confident because of boost 49.2827766074832
# accuracy among pseudolabels before boosting 98.02215189873418
# accuracy among pseudolabels after boosting 98.63577088975825
# ...

# %% [markdown]
# # Intel Pseudolabel Stats Baseline - Experiment 4 (3)

# %%
get_prediction_stats_experiment("SSAL_exp_3_att5_norestrict_3")
# Out:
# total number of predictions 16319.666666666666
# percentage of predictions that are pre-boost confident 0.1310892787842889
# percentage of predictiosn that are post-boost confident 0.1310892787842889
# total number of post-boost confident predictions 2139.3333333333335
# number of predictions that became confident with boost 0
# percentage of confident predictions that are confident because of boost 0.0
# accuracy among confident predictions before boosting 98.98722343409162
# accuracy among confident predictions after boosting 98.98722343409162
# accuracy among confident predictions which switched confident nan
#
#
# total number of pseudolabels 2139.3333333333335
# number of pseudolabels that became confident with boost 0.0
# percentage of pseudolabels that are confident because of boost 0.0
# accuracy among pseudolabels before boosting 98.98722343409162
# accuracy among pseudolabels after boosting 98.98722343409162
# accuracy among pseudolabels which switched confident nan
# ...

# %% [markdown]
# # Intel Pseudolabel Stats Mod - Experiment 4 (3)

# %%
get_prediction_stats_experiment("SSAL_exp_3_att5_norestrict_4")
# Out:
# total number of predictions 11322.333333333334
# percentage of predictions that are pre-boost confident 0.1355138811199105
# percentage of predictiosn that are post-boost confident 0.23934995731150824
# total number of post-boost confident predictions 2710.0
# number of predictions that became confident with boost 3527
# percentage of confident predictions that are confident because of boost 43.38253382533826
# accuracy among confident predictions before boosting 98.9572018248968
# accuracy among confident predictions after boosting 99.18819188191883
# accuracy among confident predictions which switched confident 99.48965126169549
#
#
# total number of pseudolabels 2710.0
# number of pseudolabels that became confident with boost 1175.6666666666667
# percentage of pseudolabels that are confident because of boost 43.38253382533826
# accuracy among pseudolabels before boosting 98.9572018248968
# accuracy among pseudolabels after boosting 99.18819188191883
# ...
